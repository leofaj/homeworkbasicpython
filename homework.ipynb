# %%
import pandas as pd

# %%
google_play_apps = pd.read_csv('Untitled Folder/googleplaystore.csv')

# %%
google_play_apps.shape
# Out:
# (10841, 13)

# %%
google_play_apps.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M     10,000+  Free     0       Everyone
# 1     967   14M    500,000+  Free     0       Everyone
# 2   87510  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
pd.value_counts(google_play_apps['Category'])
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# ...

# %%
google_play_apps.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
google_play_apps['Category'].value_counts()
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# ...

# %%
google_play_apps['Genres'].value_counts()
# Out:
# Tools                                  842
# Entertainment                          623
# Education                              549
# Medical                                463
# Business                               460
# Productivity                           424
# Sports                                 398
# Personalization                        392
# Communication                          387
# Lifestyle                              381
# Finance                                366
# Action                                 365
# Health & Fitness                       341
# Photography                            335
# Social                                 295
# News & Magazines                       283
# Shopping                               260
# Travel & Local                         257
# Dating                                 234
# Books & Reference                      231
# Arcade                                 220
# Simulation                             200
# ...

# %%
google_play_apps = pd.read_csv('Untitled Folder/googleplaystore.csv')

# %%
google_play_apps.shape
# Out:
# (10841, 13)

# %%
google_play_apps.drop_duplicates(subset='App',inplace=False)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
google_play_apps.shape
# Out:
# (10841, 13)

# %%
google_play_apps.drop_duplicates(subset='App',inplace=True)

# %%
google_play_apps.shape
# Out:
# (9660, 13)

# %%
google_play_apps[google_play_apps['Installs']=='Free']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
google_play_apps.shape
# Out:
# (9660, 13)

# %%
google_play_apps['Installs'] = google_play_apps['Installs'].apply(lambda x: x.replace('+', '') if '+' in str(x) else x)

# %%
google_play_apps.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M      10,000  Free     0       Everyone
# 1     967   14M     500,000  Free     0       Everyone
# 2   87510  8.7M   5,000,000  Free     0       Everyone
# 3  215644   25M  50,000,000  Free     0           Teen
# 4     967  2.8M     100,000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
google_play_apps['Installs']= google_play_apps['Installs'].apply(lambda x: x.replace(',','')if ',' in str(x) else x)

# %%
google_play_apps.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size  Installs  Type Price Content Rating  \
# 0     159   19M     10000  Free     0       Everyone
# 1     967   14M    500000  Free     0       Everyone
# 2   87510  8.7M   5000000  Free     0       Everyone
# 3  215644   25M  50000000  Free     0           Teen
# 4     967  2.8M    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
google_play_apps = google_play_apps[google_play_apps['Installs'] != 'Free']

# %%
google_play_apps.shape
# Out:
# (9659, 13)

# %%
google_play_apps['Installs']=google_play_apps['Installs'].astype(int)

# %%
google_play_apps[google_play_apps['App'] == 'FIFA Soccer' ]
# Out:
#               App Category  Rating  Reviews Size   Installs  Type Price  \
# 8445  FIFA Soccer   SPORTS     4.2  3909032  51M  100000000  Free     0
#
#      Content Rating  Genres   Last Updated Current Ver Android Ver
# 8445       Everyone  Sports  July 31, 2018     10.5.00  4.1 and up

# %%
google_play_apps[google_play_apps['App']=='Dropbox']
# Out:
#           App      Category  Rating  Reviews Size   Installs  Type Price  \
# 3473  Dropbox  PRODUCTIVITY     4.4  1861310  61M  500000000  Free     0
#
#      Content Rating        Genres    Last Updated         Current Ver  \
# 3473       Everyone  Productivity  August 1, 2018  Varies with device
#
#              Android Ver
# 3473  Varies with device

# %%
google_play_apps[google_play_apps['App']=='File Commander - File Manager/Explorer']
# Out:
#                                           App  Category  Rating Reviews Size  \
# 10253  File Commander - File Manager/Explorer  BUSINESS     4.3  758590  12M
#
#         Installs  Type Price Content Rating    Genres    Last Updated  \
# 10253  100000000  Free     0       Everyone  Business  August 2, 2018
#
#               Current Ver Android Ver
# 10253  Varies with device  4.1 and up

# %%
google_play_apps[google_play_apps['App']=='DU Battery Saver - Battery Charger & Battery Life']
# Out:
#                                                     App Category  Rating  \
# 8896  DU Battery Saver - Battery Charger & Battery Life    TOOLS     4.5
#
#        Reviews Size   Installs  Type Price Content Rating Genres  \
# 8896  13479633  14M  100000000  Free     0       Everyone  Tools
#
#       Last Updated Current Ver Android Ver
# 8896  June 5, 2018     4.8.7.8  4.0 and up

# %%
google_play_apps[google_play_apps['App']=='Pinterest']
# Out:
#             App Category  Rating  Reviews                Size   Installs  \
# 2552  Pinterest   SOCIAL     4.6  4305441  Varies with device  100000000
#
#       Type Price Content Rating  Genres    Last Updated         Current Ver  \
# 2552  Free     0           Teen  Social  August 3, 2018  Varies with device
#
#              Android Ver
# 2552  Varies with device

# %%
google_play_apps[google_play_apps['App']=='Flipboard: News For Our Time']
# Out:
#                                App            Category  Rating  Reviews  \
# 3755  Flipboard: News For Our Time  NEWS_AND_MAGAZINES     4.4  1284017
#
#                     Size   Installs  Type Price Content Rating  \
# 3755  Varies with device  500000000  Free     0   Everyone 10+
#
#                 Genres    Last Updated         Current Ver         Android Ver
# 3755  News & Magazines  August 3, 2018  Varies with device  Varies with device

# %%
google_play_apps[google_play_apps['App']=='Subway Surfers']
# Out:
#                  App Category  Rating   Reviews Size    Installs  Type Price  \
# 1654  Subway Surfers     GAME     4.5  27722264  76M  1000000000  Free     0
#
#      Content Rating  Genres   Last Updated Current Ver Android Ver
# 1654   Everyone 10+  Arcade  July 12, 2018      1.90.0  4.1 and up

# %%
google_play_apps[google_play_apps['App']=='WhatsApp Messenger']
# Out:
#                     App       Category  Rating   Reviews                Size  \
# 336  WhatsApp Messenger  COMMUNICATION     4.4  69119316  Varies with device
#
#        Installs  Type Price Content Rating         Genres    Last Updated  \
# 336  1000000000  Free     0       Everyone  Communication  August 3, 2018
#
#             Current Ver         Android Ver
# 336  Varies with device  Varies with device

# %%
google_play_apps[google_play_apps['Installs'] == 1000000000]
# Out:
#                                            App             Category  Rating  \
# 152                          Google Play Books  BOOKS_AND_REFERENCE     3.9
# 335   Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 336                         WhatsApp Messenger        COMMUNICATION     4.4
# 338               Google Chrome: Fast & Secure        COMMUNICATION     4.3
# 340                                      Gmail        COMMUNICATION     4.3
# 341                                   Hangouts        COMMUNICATION     4.0
# 391              Skype - free IM & video calls        COMMUNICATION     4.1
# 865                          Google Play Games        ENTERTAINMENT     4.3
# 1654                            Subway Surfers                 GAME     4.5
# 2544                                  Facebook               SOCIAL     4.1
# 2545                                 Instagram               SOCIAL     4.5
# ...

# %%
google_play_apps['Reviews']=google_play_apps['Reviews'].astype(int)

# %%
google_play_apps.sort_values(by='Reviews',ascending=False)
# Out:
#                                                      App             Category  \
# 2544                                            Facebook               SOCIAL
# 336                                   WhatsApp Messenger        COMMUNICATION
# 2545                                           Instagram               SOCIAL
# 335             Messenger – Text and Video Chat for Free        COMMUNICATION
# 1670                                      Clash of Clans                 GAME
# 4005             Clean Master- Space Cleaner & Antivirus                TOOLS
# 1654                                      Subway Surfers                 GAME
# 3665                                             YouTube        VIDEO_PLAYERS
# 7536   Security Master - Antivirus, VPN, AppLock, Boo...                TOOLS
# 1660                                        Clash Royale                 GAME
# 1655                                    Candy Crush Saga                 GAME
# ...

# %%
google_play_apps = google_play_apps[google_play_apps['Installs'] != 'NaN']
# Out:
# C:\Users\leofaj\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
google_play_apps.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type Price Content Rating  \
# 0      159   19M     10000  Free     0       Everyone
# 1      967   14M    500000  Free     0       Everyone
# 2    87510  8.7M   5000000  Free     0       Everyone
# 3   215644   25M  50000000  Free     0           Teen
# 4      967  2.8M    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
google_play_apps.shape
# Out:
# (9659, 13)

# %%
google_play_apps = google_play_apps[google_play_apps['Rating'] != 'NaN']

# %%
google_play_apps.shape
# Out:
# (9659, 13)

# %%
google_play_apps.head(20)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# ...

# %%
google_play_apps.shape
# Out:
# (9659, 13)

# %%
google_play_apps = google_play_apps[google_play_apps['Rating'] != 'NaN']
# Out:
# C:\Users\leofaj\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
google_play_apps.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#    Reviews  Size  Installs  Type Price Content Rating  \
# 0      159   19M     10000  Free     0       Everyone
# ...

# %%
google_play_apps.sort_values(by=['Installs'],ascending=False)
# Out:
#                                                    App             Category  \
# 336                                 WhatsApp Messenger        COMMUNICATION
# 152                                  Google Play Books  BOOKS_AND_REFERENCE
# 1654                                    Subway Surfers                 GAME
# 3117                         Maps - Navigate & Explore     TRAVEL_AND_LOCAL
# 340                                              Gmail        COMMUNICATION
# 2545                                         Instagram               SOCIAL
# 2544                                          Facebook               SOCIAL
# 338                       Google Chrome: Fast & Secure        COMMUNICATION
# 2554                                           Google+               SOCIAL
# 3665                                           YouTube        VIDEO_PLAYERS
# 3127                                Google Street View     TRAVEL_AND_LOCAL
# ...

# %%
google_play_apps.sort_values(by=['Rating'],ascending=False)
# Out:
#                                                      App             Category  \
# 5685                  Jobs in Canada - Emplois au Canada             BUSINESS
# 7164                                      CD CHOICE TUBE               FAMILY
# 7195                                            CE Smart                TOOLS
# 7204           TI-84 CE Graphing Calculator Manual TI 84               FAMILY
# 9341                                            EG India            LIFESTYLE
# 8063                             cx advance call blocker      PERSONALIZATION
# 7212                                           MCQ CE IT               FAMILY
# 8058                                          Oración CX            LIFESTYLE
# 9365                                Eh Bee Wallpapers HD      PERSONALIZATION
# 7239                                             CF Life               FAMILY
# 9411                                             NEMA ei             BUSINESS
# ...

# %%
google_play_apps.sort_values(['Installs', 'Rating'], ascending=[False, False])
# Out:
#                                                      App             Category  \
# 1654                                      Subway Surfers                 GAME
# 2545                                           Instagram               SOCIAL
# 2808                                       Google Photos          PHOTOGRAPHY
# 336                                   WhatsApp Messenger        COMMUNICATION
# 3234                                              Google                TOOLS
# 3454                                        Google Drive         PRODUCTIVITY
# 338                         Google Chrome: Fast & Secure        COMMUNICATION
# 340                                                Gmail        COMMUNICATION
# 865                                    Google Play Games        ENTERTAINMENT
# 3117                           Maps - Navigate & Explore     TRAVEL_AND_LOCAL
# 3665                                             YouTube        VIDEO_PLAYERS
# ...

# %%
google_play_apps_GAME= google_play_apps[google_play_apps.Category =="GAME"]

# %%
google_play_apps_GAME.sort_values(['Installs', 'Rating'], ascending=[False, False])
# Out:
#                                                      App Category  Rating  \
# 1654                                      Subway Surfers     GAME     4.5
# 1722                                      My Talking Tom     GAME     4.5
# 1655                                    Candy Crush Saga     GAME     4.4
# 1661                                        Temple Run 2     GAME     4.3
# 1662                                                 Pou     GAME     4.3
# 1763                                      Piano Tiles 2™     GAME     4.7
# 1660                                        Clash Royale     GAME     4.6
# 1670                                      Clash of Clans     GAME     4.6
# 1699    Sniper 3D Gun Shooter: Free Shooting Games - FPS     GAME     4.6
# 1709                                         Score! Hero     GAME     4.6
# 1737                                Talking Tom Gold Run     GAME     4.6
# 1739                            Dream League Soccer 2018     GAME     4.6
# ...
